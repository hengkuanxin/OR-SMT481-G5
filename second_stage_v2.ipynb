# %%
import pandas as pd
import numpy as np
import pulp
from first_stage_func import first_stage

# %%
first_stage_results = first_stage()
allocation = first_stage_results[2]

# %%
data_directory = 'data/'
stations = pd.read_csv(f'{data_directory}/station_with_demand.csv')
percentage_map = {
    'Lowest': 0.20,
    'Low': 0.40,
    'Medium': 0.60,
    'Highest': 0.80
}
stations['DEMAND'] = stations['DEMAND_CATEGORY'].map(percentage_map) * stations['capacity']
distance_matrix = pd.read_csv(f'{data_directory}/distance_matrix.csv', index_col=0).to_numpy()

# %%
# Parameters
S = len(stations)  # Number of bike stations (adjust as needed)
scenarios = ["Cloudy", "Rainy", "Sunny", "Clear"]
probabilities = {
    "Cloudy": 0.3, 
    "Rainy": 0.2, 
    "Sunny": 0.1, 
    "Clear": 0.4
}
penalty_unmet_demand = 1000  # Penalty for unmet demand
penalty_over_capacity = 500  # Penalty for exceeding capacity

# Randomly generated input data
cij = distance_matrix # Cost matrix for relocation
A = sum(allocation)  # Total initial bike allocation
initial_bikes = allocation
Ci = stations["capacity"]  # Capacity for each station
Di = stations["DEMAND"]
weather_factors = {
    "Cloudy": 0.8, 
    "Rainy": 1.2, 
    "Sunny": 1.0, 
    "Clear": 0.9
}

# Decision Variables
model = pulp.LpProblem("Bike_Relocation_Optimization", pulp.LpMinimize)
yijk = pulp.LpVariable.dicts("yijk", [(i, j, k) for i in range(S) for j in range(S) for k in scenarios], lowBound=0, cat='Integer')
xik = pulp.LpVariable.dicts("xik", [(i, k) for i in range(S) for k in scenarios], lowBound=0, cat='Integer')

# Penalty Variables
unmet_demand = pulp.LpVariable.dicts("unmet_demand", [(i, k) for i in range(S) for k in scenarios], lowBound=0, cat='Integer')
over_capacity = pulp.LpVariable.dicts("over_capacity", [(i, k) for i in range(S) for k in scenarios], lowBound=0, cat='Integer')

# Objective Function: Minimize relocation cost + penalties
model += (
    pulp.lpSum(yijk[i, j, k] * cij[i][j] * probabilities[k] for i in range(S) for j in range(S) for k in scenarios) +
    penalty_unmet_demand * pulp.lpSum(unmet_demand[i, k] for i in range(S) for k in scenarios) +
    penalty_over_capacity * pulp.lpSum(over_capacity[i, k] for i in range(S) for k in scenarios)
)
print("Model as been defined.")

# Constraints

# Total allocation for each scenario cannot exceed initial allocation
for k in scenarios:
    model += pulp.lpSum(xik[i, k] for i in range(S)) <= A, f"Allocation_Constraint_Scenario_{k}"
print("Constraint 1 Defined.")

# Define final number of bikes with relaxed constraint
for i in range(S):
    for k in scenarios:
        model += xik[i, k] == initial_bikes[i] + pulp.lpSum(yijk[j, i, k] for j in range(S)) - pulp.lpSum(yijk[i, j, k] for j in range(S)), f"Final_Bikes_Constraint_{i}_{k}"
print("Constraint 2 Defined.")

# Demand satisfaction with penalties
for i in range(S):
    for k in scenarios:
        expected_demand = Di[i] * weather_factors[k]
        model += xik[i, k] + unmet_demand[i, k] >= expected_demand, f"Demand_Constraint_{i}_{k}"
print("Constraint 3 Defined.")

# Capacity constraint with penalties
for i in range(S):
    for k in scenarios:
        model += xik[i, k] - over_capacity[i, k] <= Ci[i], f"Capacity_Constraint_{i}_{k}"
print("Constraint 4 Defined.")

# Solve the model
print("Solving...")
status = model.solve()

# Output results
if status == pulp.LpStatusOptimal:
    print(f"Optimal Solution Found with Total Cost: {pulp.value(model.objective):.2f}")
else:
    print("No optimal solution found.")
# Out:
# Model as been defined.
# Constraint 1 Defined.
# Constraint 2 Defined.
# Constraint 3 Defined.
# Constraint 4 Defined.
# Solving...
# Optimal Solution Found with Total Cost: 6283942.53

# %%
# Output results
if status == pulp.LpStatusOptimal:
    print(f"Optimal Solution Found with Total Cost: {pulp.value(model.objective):.2f}\n")
    
    # Print the allocation, unmet demand, and over-capacity penalties for each station and scenario
    print("Bike Allocations, Unmet Demand, and Over Capacity Penalties:")
    for i in range(S):
        for k in scenarios:
            print(f"Station {i}, Scenario {k}:")
            print(f"  Bikes Allocated (xik) = {xik[i, k].varValue}")
            print(f"  Unmet Demand Penalty = {unmet_demand[i, k].varValue}")
            print(f"  Over Capacity Penalty = {over_capacity[i, k].varValue}")
    print("\nRelocation Plan:")

    # Print the relocation details (yijk) only if bikes are being relocated
    for k in scenarios:
        print(f"\nScenario {k} Relocations:")
        relocation_count = 0
        for i in range(S):
            for j in range(S):
                if i != j and yijk[i, j, k].varValue > 0:
                    print(f"  Relocate {yijk[i, j, k].varValue} bikes from Station {i} to Station {j}")
                    relocation_count += 1
        if relocation_count == 0:
            print("  No relocations needed for this scenario.")
else:
    print("No optimal solution found.")
# Out:
# Optimal Solution Found with Total Cost: 6283942.53
#
# Bike Allocations, Unmet Demand, and Over Capacity Penalties:
# Station 0, Scenario Cloudy:
#   Bikes Allocated (xik) = 38.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 0, Scenario Rainy:
#   Bikes Allocated (xik) = 14.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 0, Scenario Sunny:
#   Bikes Allocated (xik) = 12.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 0, Scenario Clear:
#   Bikes Allocated (xik) = 33.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 1, Scenario Cloudy:
#   Bikes Allocated (xik) = 39.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 1, Scenario Rainy:
#   Bikes Allocated (xik) = 33.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 1, Scenario Sunny:
#   Bikes Allocated (xik) = 28.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 1, Scenario Clear:
#   Bikes Allocated (xik) = 27.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 2, Scenario Cloudy:
#   Bikes Allocated (xik) = 5.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 2, Scenario Rainy:
#   Bikes Allocated (xik) = 7.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 2, Scenario Sunny:
#   Bikes Allocated (xik) = 6.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 2, Scenario Clear:
#   Bikes Allocated (xik) = 6.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 3, Scenario Cloudy:
#   Bikes Allocated (xik) = 25.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 3, Scenario Rainy:
#   Bikes Allocated (xik) = 20.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 3, Scenario Sunny:
#   Bikes Allocated (xik) = 17.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 3, Scenario Clear:
#   Bikes Allocated (xik) = 19.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 4, Scenario Cloudy:
#   Bikes Allocated (xik) = 73.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 4, Scenario Rainy:
#   Bikes Allocated (xik) = 29.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 4, Scenario Sunny:
#   Bikes Allocated (xik) = 24.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 4, Scenario Clear:
#   Bikes Allocated (xik) = 67.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 5, Scenario Cloudy:
#   Bikes Allocated (xik) = 17.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 5, Scenario Rainy:
#   Bikes Allocated (xik) = 20.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 5, Scenario Sunny:
#   Bikes Allocated (xik) = 17.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 5, Scenario Clear:
#   Bikes Allocated (xik) = 15.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 6, Scenario Cloudy:
#   Bikes Allocated (xik) = 29.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 6, Scenario Rainy:
#   Bikes Allocated (xik) = 25.0
#   Unmet Demand Penalty = 19.0
#   Over Capacity Penalty = 0.0
# Station 6, Scenario Sunny:
#   Bikes Allocated (xik) = 36.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 6, Scenario Clear:
#   Bikes Allocated (xik) = 33.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 7, Scenario Cloudy:
#   Bikes Allocated (xik) = 24.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 7, Scenario Rainy:
#   Bikes Allocated (xik) = 36.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 7, Scenario Sunny:
#   Bikes Allocated (xik) = 30.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 7, Scenario Clear:
#   Bikes Allocated (xik) = 27.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 8, Scenario Cloudy:
#   Bikes Allocated (xik) = 8.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 8, Scenario Rainy:
#   Bikes Allocated (xik) = 11.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 8, Scenario Sunny:
#   Bikes Allocated (xik) = 9.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 8, Scenario Clear:
#   Bikes Allocated (xik) = 8.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 9, Scenario Cloudy:
#   Bikes Allocated (xik) = 8.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 9, Scenario Rainy:
#   Bikes Allocated (xik) = 12.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 9, Scenario Sunny:
#   Bikes Allocated (xik) = 10.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 9, Scenario Clear:
#   Bikes Allocated (xik) = 9.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 10, Scenario Cloudy:
#   Bikes Allocated (xik) = 15.0
#   Unmet Demand Penalty = 5.0
#   Over Capacity Penalty = 0.0
# Station 10, Scenario Rainy:
#   Bikes Allocated (xik) = 8.0
#   Unmet Demand Penalty = 22.0
#   Over Capacity Penalty = 0.0
# Station 10, Scenario Sunny:
#   Bikes Allocated (xik) = 25.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 10, Scenario Clear:
#   Bikes Allocated (xik) = 12.0
#   Unmet Demand Penalty = 11.0
#   Over Capacity Penalty = 0.0
# Station 11, Scenario Cloudy:
#   Bikes Allocated (xik) = 9.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 11, Scenario Rainy:
#   Bikes Allocated (xik) = 7.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 11, Scenario Sunny:
#   Bikes Allocated (xik) = 8.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 11, Scenario Clear:
#   Bikes Allocated (xik) = 9.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 12, Scenario Cloudy:
#   Bikes Allocated (xik) = 62.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 12, Scenario Rainy:
#   Bikes Allocated (xik) = 36.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 12, Scenario Sunny:
#   Bikes Allocated (xik) = 54.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 12, Scenario Clear:
#   Bikes Allocated (xik) = 62.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 13, Scenario Cloudy:
#   Bikes Allocated (xik) = 15.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 13, Scenario Rainy:
#   Bikes Allocated (xik) = 11.0
#   Unmet Demand Penalty = 12.0
#   Over Capacity Penalty = 0.0
# Station 13, Scenario Sunny:
#   Bikes Allocated (xik) = 19.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 13, Scenario Clear:
#   Bikes Allocated (xik) = 11.0
#   Unmet Demand Penalty = 6.0
#   Over Capacity Penalty = 0.0
# Station 14, Scenario Cloudy:
#   Bikes Allocated (xik) = 16.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 14, Scenario Rainy:
#   Bikes Allocated (xik) = 23.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 14, Scenario Sunny:
#   Bikes Allocated (xik) = 19.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 14, Scenario Clear:
#   Bikes Allocated (xik) = 17.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 15, Scenario Cloudy:
#   Bikes Allocated (xik) = 10.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 15, Scenario Rainy:
#   Bikes Allocated (xik) = 15.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 15, Scenario Sunny:
#   Bikes Allocated (xik) = 13.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 15, Scenario Clear:
#   Bikes Allocated (xik) = 12.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 16, Scenario Cloudy:
#   Bikes Allocated (xik) = 36.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 16, Scenario Rainy:
#   Bikes Allocated (xik) = 0.0
#   Unmet Demand Penalty = 54.0
#   Over Capacity Penalty = 0.0
# Station 16, Scenario Sunny:
#   Bikes Allocated (xik) = 0.0
#   Unmet Demand Penalty = 45.0
#   Over Capacity Penalty = 0.0
# Station 16, Scenario Clear:
#   Bikes Allocated (xik) = 0.0
#   Unmet Demand Penalty = 41.0
#   Over Capacity Penalty = 0.0
# Station 17, Scenario Cloudy:
#   Bikes Allocated (xik) = 9.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 17, Scenario Rainy:
#   Bikes Allocated (xik) = 7.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 17, Scenario Sunny:
#   Bikes Allocated (xik) = 8.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 17, Scenario Clear:
#   Bikes Allocated (xik) = 9.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 18, Scenario Cloudy:
#   Bikes Allocated (xik) = 4.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 18, Scenario Rainy:
#   Bikes Allocated (xik) = 6.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 18, Scenario Sunny:
#   Bikes Allocated (xik) = 5.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 18, Scenario Clear:
#   Bikes Allocated (xik) = 3.0
#   Unmet Demand Penalty = 1.0
#   Over Capacity Penalty = 0.0
# Station 19, Scenario Cloudy:
#   Bikes Allocated (xik) = 23.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 19, Scenario Rainy:
#   Bikes Allocated (xik) = 24.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 19, Scenario Sunny:
#   Bikes Allocated (xik) = 20.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 19, Scenario Clear:
#   Bikes Allocated (xik) = 18.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 20, Scenario Cloudy:
#   Bikes Allocated (xik) = 26.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 20, Scenario Rainy:
#   Bikes Allocated (xik) = 38.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 20, Scenario Sunny:
#   Bikes Allocated (xik) = 32.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 20, Scenario Clear:
#   Bikes Allocated (xik) = 29.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 21, Scenario Cloudy:
#   Bikes Allocated (xik) = 18.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 21, Scenario Rainy:
#   Bikes Allocated (xik) = 27.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 21, Scenario Sunny:
#   Bikes Allocated (xik) = 22.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 21, Scenario Clear:
#   Bikes Allocated (xik) = 20.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 22, Scenario Cloudy:
#   Bikes Allocated (xik) = 16.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 22, Scenario Rainy:
#   Bikes Allocated (xik) = 24.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 22, Scenario Sunny:
#   Bikes Allocated (xik) = 20.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 22, Scenario Clear:
#   Bikes Allocated (xik) = 18.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 23, Scenario Cloudy:
#   Bikes Allocated (xik) = 34.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 23, Scenario Rainy:
#   Bikes Allocated (xik) = 30.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 23, Scenario Sunny:
#   Bikes Allocated (xik) = 25.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 23, Scenario Clear:
#   Bikes Allocated (xik) = 32.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 24, Scenario Cloudy:
#   Bikes Allocated (xik) = 5.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 24, Scenario Rainy:
#   Bikes Allocated (xik) = 8.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 24, Scenario Sunny:
#   Bikes Allocated (xik) = 7.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 24, Scenario Clear:
#   Bikes Allocated (xik) = 6.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 25, Scenario Cloudy:
#   Bikes Allocated (xik) = 11.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 25, Scenario Rainy:
#   Bikes Allocated (xik) = 11.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 25, Scenario Sunny:
#   Bikes Allocated (xik) = 11.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 25, Scenario Clear:
#   Bikes Allocated (xik) = 11.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 26, Scenario Cloudy:
#   Bikes Allocated (xik) = 9.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 26, Scenario Rainy:
#   Bikes Allocated (xik) = 7.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 26, Scenario Sunny:
#   Bikes Allocated (xik) = 8.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 26, Scenario Clear:
#   Bikes Allocated (xik) = 8.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 27, Scenario Cloudy:
#   Bikes Allocated (xik) = 24.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 27, Scenario Rainy:
#   Bikes Allocated (xik) = 9.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 27, Scenario Sunny:
#   Bikes Allocated (xik) = 17.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 27, Scenario Clear:
#   Bikes Allocated (xik) = 20.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 28, Scenario Cloudy:
#   Bikes Allocated (xik) = 48.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 28, Scenario Rainy:
#   Bikes Allocated (xik) = 17.0
#   Unmet Demand Penalty = 55.0
#   Over Capacity Penalty = 0.0
# Station 28, Scenario Sunny:
#   Bikes Allocated (xik) = 60.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 28, Scenario Clear:
#   Bikes Allocated (xik) = 17.0
#   Unmet Demand Penalty = 37.0
#   Over Capacity Penalty = 0.0
# Station 29, Scenario Cloudy:
#   Bikes Allocated (xik) = 10.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 29, Scenario Rainy:
#   Bikes Allocated (xik) = 15.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 29, Scenario Sunny:
#   Bikes Allocated (xik) = 13.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 29, Scenario Clear:
#   Bikes Allocated (xik) = 12.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 30, Scenario Cloudy:
#   Bikes Allocated (xik) = 8.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 30, Scenario Rainy:
#   Bikes Allocated (xik) = 5.0
#   Unmet Demand Penalty = 7.0
#   Over Capacity Penalty = 0.0
# Station 30, Scenario Sunny:
#   Bikes Allocated (xik) = 10.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 30, Scenario Clear:
#   Bikes Allocated (xik) = 5.0
#   Unmet Demand Penalty = 4.0
#   Over Capacity Penalty = 0.0
# Station 31, Scenario Cloudy:
#   Bikes Allocated (xik) = 4.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 31, Scenario Rainy:
#   Bikes Allocated (xik) = 6.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 31, Scenario Sunny:
#   Bikes Allocated (xik) = 5.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 31, Scenario Clear:
#   Bikes Allocated (xik) = 4.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 32, Scenario Cloudy:
#   Bikes Allocated (xik) = 4.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 32, Scenario Rainy:
#   Bikes Allocated (xik) = 5.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 32, Scenario Sunny:
#   Bikes Allocated (xik) = 4.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 32, Scenario Clear:
#   Bikes Allocated (xik) = 4.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 33, Scenario Cloudy:
#   Bikes Allocated (xik) = 24.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 33, Scenario Rainy:
#   Bikes Allocated (xik) = 36.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 33, Scenario Sunny:
#   Bikes Allocated (xik) = 30.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 33, Scenario Clear:
#   Bikes Allocated (xik) = 27.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 34, Scenario Cloudy:
#   Bikes Allocated (xik) = 17.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 34, Scenario Rainy:
#   Bikes Allocated (xik) = 12.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 34, Scenario Sunny:
#   Bikes Allocated (xik) = 10.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 34, Scenario Clear:
#   Bikes Allocated (xik) = 10.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 35, Scenario Cloudy:
#   Bikes Allocated (xik) = 41.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 35, Scenario Rainy:
#   Bikes Allocated (xik) = 24.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 35, Scenario Sunny:
#   Bikes Allocated (xik) = 20.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 35, Scenario Clear:
#   Bikes Allocated (xik) = 18.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 36, Scenario Cloudy:
#   Bikes Allocated (xik) = 51.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 36, Scenario Rainy:
#   Bikes Allocated (xik) = 42.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 36, Scenario Sunny:
#   Bikes Allocated (xik) = 35.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 36, Scenario Clear:
#   Bikes Allocated (xik) = 47.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 37, Scenario Cloudy:
#   Bikes Allocated (xik) = 18.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 37, Scenario Rainy:
#   Bikes Allocated (xik) = 26.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 37, Scenario Sunny:
#   Bikes Allocated (xik) = 22.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 37, Scenario Clear:
#   Bikes Allocated (xik) = 20.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 38, Scenario Cloudy:
#   Bikes Allocated (xik) = 8.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 38, Scenario Rainy:
#   Bikes Allocated (xik) = 8.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 38, Scenario Sunny:
#   Bikes Allocated (xik) = 8.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 38, Scenario Clear:
#   Bikes Allocated (xik) = 8.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 39, Scenario Cloudy:
#   Bikes Allocated (xik) = 26.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 39, Scenario Rainy:
#   Bikes Allocated (xik) = 16.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 39, Scenario Sunny:
#   Bikes Allocated (xik) = 14.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 39, Scenario Clear:
#   Bikes Allocated (xik) = 21.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 40, Scenario Cloudy:
#   Bikes Allocated (xik) = 24.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 40, Scenario Rainy:
#   Bikes Allocated (xik) = 3.0
#   Unmet Demand Penalty = 33.0
#   Over Capacity Penalty = 0.0
# Station 40, Scenario Sunny:
#   Bikes Allocated (xik) = 9.0
#   Unmet Demand Penalty = 21.0
#   Over Capacity Penalty = 0.0
# Station 40, Scenario Clear:
#   Bikes Allocated (xik) = 16.0
#   Unmet Demand Penalty = 11.0
#   Over Capacity Penalty = 0.0
# Station 41, Scenario Cloudy:
#   Bikes Allocated (xik) = 22.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 41, Scenario Rainy:
#   Bikes Allocated (xik) = 22.0
#   Unmet Demand Penalty = 6.0
#   Over Capacity Penalty = 0.0
# Station 41, Scenario Sunny:
#   Bikes Allocated (xik) = 23.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 41, Scenario Clear:
#   Bikes Allocated (xik) = 22.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 42, Scenario Cloudy:
#   Bikes Allocated (xik) = 21.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 42, Scenario Rainy:
#   Bikes Allocated (xik) = 31.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 42, Scenario Sunny:
#   Bikes Allocated (xik) = 26.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 42, Scenario Clear:
#   Bikes Allocated (xik) = 24.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 43, Scenario Cloudy:
#   Bikes Allocated (xik) = 15.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 43, Scenario Rainy:
#   Bikes Allocated (xik) = 9.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 43, Scenario Sunny:
#   Bikes Allocated (xik) = 15.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 43, Scenario Clear:
#   Bikes Allocated (xik) = 15.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 44, Scenario Cloudy:
#   Bikes Allocated (xik) = 17.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 44, Scenario Rainy:
#   Bikes Allocated (xik) = 19.0
#   Unmet Demand Penalty = 6.0
#   Over Capacity Penalty = 0.0
# Station 44, Scenario Sunny:
#   Bikes Allocated (xik) = 21.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 44, Scenario Clear:
#   Bikes Allocated (xik) = 19.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 45, Scenario Cloudy:
#   Bikes Allocated (xik) = 30.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 45, Scenario Rainy:
#   Bikes Allocated (xik) = 26.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 45, Scenario Sunny:
#   Bikes Allocated (xik) = 28.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 45, Scenario Clear:
#   Bikes Allocated (xik) = 30.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 46, Scenario Cloudy:
#   Bikes Allocated (xik) = 14.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 46, Scenario Rainy:
#   Bikes Allocated (xik) = 19.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 46, Scenario Sunny:
#   Bikes Allocated (xik) = 16.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 46, Scenario Clear:
#   Bikes Allocated (xik) = 14.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 47, Scenario Cloudy:
#   Bikes Allocated (xik) = 11.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 47, Scenario Rainy:
#   Bikes Allocated (xik) = 8.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 47, Scenario Sunny:
#   Bikes Allocated (xik) = 10.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 47, Scenario Clear:
#   Bikes Allocated (xik) = 11.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 48, Scenario Cloudy:
#   Bikes Allocated (xik) = 5.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 48, Scenario Rainy:
#   Bikes Allocated (xik) = 5.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 48, Scenario Sunny:
#   Bikes Allocated (xik) = 5.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 48, Scenario Clear:
#   Bikes Allocated (xik) = 5.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 49, Scenario Cloudy:
#   Bikes Allocated (xik) = 32.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 49, Scenario Rainy:
#   Bikes Allocated (xik) = 39.0
#   Unmet Demand Penalty = 8.0
#   Over Capacity Penalty = 0.0
# Station 49, Scenario Sunny:
#   Bikes Allocated (xik) = 39.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 49, Scenario Clear:
#   Bikes Allocated (xik) = 36.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 50, Scenario Cloudy:
#   Bikes Allocated (xik) = 26.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 50, Scenario Rainy:
#   Bikes Allocated (xik) = 33.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 50, Scenario Sunny:
#   Bikes Allocated (xik) = 27.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 50, Scenario Clear:
#   Bikes Allocated (xik) = 25.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 51, Scenario Cloudy:
#   Bikes Allocated (xik) = 12.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 51, Scenario Rainy:
#   Bikes Allocated (xik) = 12.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 51, Scenario Sunny:
#   Bikes Allocated (xik) = 12.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 51, Scenario Clear:
#   Bikes Allocated (xik) = 12.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 52, Scenario Cloudy:
#   Bikes Allocated (xik) = 25.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 52, Scenario Rainy:
#   Bikes Allocated (xik) = 15.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 52, Scenario Sunny:
#   Bikes Allocated (xik) = 20.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 52, Scenario Clear:
#   Bikes Allocated (xik) = 24.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 53, Scenario Cloudy:
#   Bikes Allocated (xik) = 13.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 53, Scenario Rainy:
#   Bikes Allocated (xik) = 19.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 53, Scenario Sunny:
#   Bikes Allocated (xik) = 16.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 53, Scenario Clear:
#   Bikes Allocated (xik) = 15.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 54, Scenario Cloudy:
#   Bikes Allocated (xik) = 8.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 54, Scenario Rainy:
#   Bikes Allocated (xik) = 11.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 54, Scenario Sunny:
#   Bikes Allocated (xik) = 9.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 54, Scenario Clear:
#   Bikes Allocated (xik) = 8.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 55, Scenario Cloudy:
#   Bikes Allocated (xik) = 29.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 55, Scenario Rainy:
#   Bikes Allocated (xik) = 24.0
#   Unmet Demand Penalty = 20.0
#   Over Capacity Penalty = 0.0
# Station 55, Scenario Sunny:
#   Bikes Allocated (xik) = 36.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 55, Scenario Clear:
#   Bikes Allocated (xik) = 33.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 56, Scenario Cloudy:
#   Bikes Allocated (xik) = 11.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 56, Scenario Rainy:
#   Bikes Allocated (xik) = 12.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 56, Scenario Sunny:
#   Bikes Allocated (xik) = 10.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 56, Scenario Clear:
#   Bikes Allocated (xik) = 9.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 57, Scenario Cloudy:
#   Bikes Allocated (xik) = 4.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 57, Scenario Rainy:
#   Bikes Allocated (xik) = 5.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 57, Scenario Sunny:
#   Bikes Allocated (xik) = 4.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 57, Scenario Clear:
#   Bikes Allocated (xik) = 4.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 58, Scenario Cloudy:
#   Bikes Allocated (xik) = 4.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 58, Scenario Rainy:
#   Bikes Allocated (xik) = 6.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 58, Scenario Sunny:
#   Bikes Allocated (xik) = 5.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 58, Scenario Clear:
#   Bikes Allocated (xik) = 4.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 59, Scenario Cloudy:
#   Bikes Allocated (xik) = 34.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 59, Scenario Rainy:
#   Bikes Allocated (xik) = 18.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 59, Scenario Sunny:
#   Bikes Allocated (xik) = 15.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 59, Scenario Clear:
#   Bikes Allocated (xik) = 34.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 60, Scenario Cloudy:
#   Bikes Allocated (xik) = 45.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 60, Scenario Rainy:
#   Bikes Allocated (xik) = 30.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 60, Scenario Sunny:
#   Bikes Allocated (xik) = 25.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 60, Scenario Clear:
#   Bikes Allocated (xik) = 45.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 61, Scenario Cloudy:
#   Bikes Allocated (xik) = 29.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 61, Scenario Rainy:
#   Bikes Allocated (xik) = 44.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 61, Scenario Sunny:
#   Bikes Allocated (xik) = 36.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 61, Scenario Clear:
#   Bikes Allocated (xik) = 33.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 62, Scenario Cloudy:
#   Bikes Allocated (xik) = 9.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 62, Scenario Rainy:
#   Bikes Allocated (xik) = 13.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 62, Scenario Sunny:
#   Bikes Allocated (xik) = 11.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 62, Scenario Clear:
#   Bikes Allocated (xik) = 10.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 63, Scenario Cloudy:
#   Bikes Allocated (xik) = 14.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 63, Scenario Rainy:
#   Bikes Allocated (xik) = 20.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 63, Scenario Sunny:
#   Bikes Allocated (xik) = 17.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 63, Scenario Clear:
#   Bikes Allocated (xik) = 15.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 64, Scenario Cloudy:
#   Bikes Allocated (xik) = 14.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 64, Scenario Rainy:
#   Bikes Allocated (xik) = 14.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 64, Scenario Sunny:
#   Bikes Allocated (xik) = 14.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 64, Scenario Clear:
#   Bikes Allocated (xik) = 14.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 65, Scenario Cloudy:
#   Bikes Allocated (xik) = 28.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 65, Scenario Rainy:
#   Bikes Allocated (xik) = 42.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 65, Scenario Sunny:
#   Bikes Allocated (xik) = 35.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 65, Scenario Clear:
#   Bikes Allocated (xik) = 31.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 66, Scenario Cloudy:
#   Bikes Allocated (xik) = 22.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 66, Scenario Rainy:
#   Bikes Allocated (xik) = 33.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 66, Scenario Sunny:
#   Bikes Allocated (xik) = 27.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 66, Scenario Clear:
#   Bikes Allocated (xik) = 25.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 67, Scenario Cloudy:
#   Bikes Allocated (xik) = 8.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 67, Scenario Rainy:
#   Bikes Allocated (xik) = 12.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 67, Scenario Sunny:
#   Bikes Allocated (xik) = 10.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 67, Scenario Clear:
#   Bikes Allocated (xik) = 9.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 68, Scenario Cloudy:
#   Bikes Allocated (xik) = 21.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 68, Scenario Rainy:
#   Bikes Allocated (xik) = 20.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 68, Scenario Sunny:
#   Bikes Allocated (xik) = 21.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 68, Scenario Clear:
#   Bikes Allocated (xik) = 21.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 69, Scenario Cloudy:
#   Bikes Allocated (xik) = 23.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 69, Scenario Rainy:
#   Bikes Allocated (xik) = 28.0
#   Unmet Demand Penalty = 6.0
#   Over Capacity Penalty = 0.0
# Station 69, Scenario Sunny:
#   Bikes Allocated (xik) = 28.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 69, Scenario Clear:
#   Bikes Allocated (xik) = 25.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 70, Scenario Cloudy:
#   Bikes Allocated (xik) = 27.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 70, Scenario Rainy:
#   Bikes Allocated (xik) = 13.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 70, Scenario Sunny:
#   Bikes Allocated (xik) = 27.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 70, Scenario Clear:
#   Bikes Allocated (xik) = 27.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 71, Scenario Cloudy:
#   Bikes Allocated (xik) = 28.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 71, Scenario Rainy:
#   Bikes Allocated (xik) = 42.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 71, Scenario Sunny:
#   Bikes Allocated (xik) = 35.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 71, Scenario Clear:
#   Bikes Allocated (xik) = 31.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 72, Scenario Cloudy:
#   Bikes Allocated (xik) = 34.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 72, Scenario Rainy:
#   Bikes Allocated (xik) = 50.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 72, Scenario Sunny:
#   Bikes Allocated (xik) = 42.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 72, Scenario Clear:
#   Bikes Allocated (xik) = 38.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 73, Scenario Cloudy:
#   Bikes Allocated (xik) = 31.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 73, Scenario Rainy:
#   Bikes Allocated (xik) = 31.0
#   Unmet Demand Penalty = 5.0
#   Over Capacity Penalty = 0.0
# Station 73, Scenario Sunny:
#   Bikes Allocated (xik) = 30.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 73, Scenario Clear:
#   Bikes Allocated (xik) = 31.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 74, Scenario Cloudy:
#   Bikes Allocated (xik) = 22.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 74, Scenario Rainy:
#   Bikes Allocated (xik) = 19.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 74, Scenario Sunny:
#   Bikes Allocated (xik) = 16.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 74, Scenario Clear:
#   Bikes Allocated (xik) = 16.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 75, Scenario Cloudy:
#   Bikes Allocated (xik) = 18.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 75, Scenario Rainy:
#   Bikes Allocated (xik) = 15.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 75, Scenario Sunny:
#   Bikes Allocated (xik) = 17.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 75, Scenario Clear:
#   Bikes Allocated (xik) = 17.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 76, Scenario Cloudy:
#   Bikes Allocated (xik) = 9.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 76, Scenario Rainy:
#   Bikes Allocated (xik) = 13.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 76, Scenario Sunny:
#   Bikes Allocated (xik) = 11.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 76, Scenario Clear:
#   Bikes Allocated (xik) = 10.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 77, Scenario Cloudy:
#   Bikes Allocated (xik) = 25.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 77, Scenario Rainy:
#   Bikes Allocated (xik) = 20.0
#   Unmet Demand Penalty = 17.0
#   Over Capacity Penalty = 0.0
# Station 77, Scenario Sunny:
#   Bikes Allocated (xik) = 31.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 77, Scenario Clear:
#   Bikes Allocated (xik) = 28.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 78, Scenario Cloudy:
#   Bikes Allocated (xik) = 42.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 78, Scenario Rainy:
#   Bikes Allocated (xik) = 41.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 78, Scenario Sunny:
#   Bikes Allocated (xik) = 34.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 78, Scenario Clear:
#   Bikes Allocated (xik) = 40.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 79, Scenario Cloudy:
#   Bikes Allocated (xik) = 20.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 79, Scenario Rainy:
#   Bikes Allocated (xik) = 30.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 79, Scenario Sunny:
#   Bikes Allocated (xik) = 25.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 79, Scenario Clear:
#   Bikes Allocated (xik) = 23.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 80, Scenario Cloudy:
#   Bikes Allocated (xik) = 4.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 80, Scenario Rainy:
#   Bikes Allocated (xik) = 6.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 80, Scenario Sunny:
#   Bikes Allocated (xik) = 5.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 80, Scenario Clear:
#   Bikes Allocated (xik) = 5.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 81, Scenario Cloudy:
#   Bikes Allocated (xik) = 25.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 81, Scenario Rainy:
#   Bikes Allocated (xik) = 13.0
#   Unmet Demand Penalty = 24.0
#   Over Capacity Penalty = 0.0
# Station 81, Scenario Sunny:
#   Bikes Allocated (xik) = 31.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 81, Scenario Clear:
#   Bikes Allocated (xik) = 28.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 82, Scenario Cloudy:
#   Bikes Allocated (xik) = 8.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 82, Scenario Rainy:
#   Bikes Allocated (xik) = 12.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 82, Scenario Sunny:
#   Bikes Allocated (xik) = 10.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 82, Scenario Clear:
#   Bikes Allocated (xik) = 9.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 83, Scenario Cloudy:
#   Bikes Allocated (xik) = 17.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 83, Scenario Rainy:
#   Bikes Allocated (xik) = 15.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 83, Scenario Sunny:
#   Bikes Allocated (xik) = 13.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 83, Scenario Clear:
#   Bikes Allocated (xik) = 17.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 84, Scenario Cloudy:
#   Bikes Allocated (xik) = 19.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 84, Scenario Rainy:
#   Bikes Allocated (xik) = 20.0
#   Unmet Demand Penalty = 9.0
#   Over Capacity Penalty = 0.0
# Station 84, Scenario Sunny:
#   Bikes Allocated (xik) = 24.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 84, Scenario Clear:
#   Bikes Allocated (xik) = 22.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 85, Scenario Cloudy:
#   Bikes Allocated (xik) = 25.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 85, Scenario Rainy:
#   Bikes Allocated (xik) = 38.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 85, Scenario Sunny:
#   Bikes Allocated (xik) = 32.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 85, Scenario Clear:
#   Bikes Allocated (xik) = 29.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 86, Scenario Cloudy:
#   Bikes Allocated (xik) = 13.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 86, Scenario Rainy:
#   Bikes Allocated (xik) = 20.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 86, Scenario Sunny:
#   Bikes Allocated (xik) = 16.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 86, Scenario Clear:
#   Bikes Allocated (xik) = 15.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 87, Scenario Cloudy:
#   Bikes Allocated (xik) = 4.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 87, Scenario Rainy:
#   Bikes Allocated (xik) = 6.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 87, Scenario Sunny:
#   Bikes Allocated (xik) = 5.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 87, Scenario Clear:
#   Bikes Allocated (xik) = 5.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 88, Scenario Cloudy:
#   Bikes Allocated (xik) = 47.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 88, Scenario Rainy:
#   Bikes Allocated (xik) = 55.0
#   Unmet Demand Penalty = 2.0
#   Over Capacity Penalty = 0.0
# Station 88, Scenario Sunny:
#   Bikes Allocated (xik) = 47.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 88, Scenario Clear:
#   Bikes Allocated (xik) = 43.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 89, Scenario Cloudy:
#   Bikes Allocated (xik) = 19.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 89, Scenario Rainy:
#   Bikes Allocated (xik) = 29.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 89, Scenario Sunny:
#   Bikes Allocated (xik) = 24.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 89, Scenario Clear:
#   Bikes Allocated (xik) = 22.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 90, Scenario Cloudy:
#   Bikes Allocated (xik) = 25.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 90, Scenario Rainy:
#   Bikes Allocated (xik) = 0.0
#   Unmet Demand Penalty = 37.0
#   Over Capacity Penalty = 0.0
# Station 90, Scenario Sunny:
#   Bikes Allocated (xik) = 31.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 90, Scenario Clear:
#   Bikes Allocated (xik) = 28.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 91, Scenario Cloudy:
#   Bikes Allocated (xik) = 4.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 91, Scenario Rainy:
#   Bikes Allocated (xik) = 6.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 91, Scenario Sunny:
#   Bikes Allocated (xik) = 5.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 91, Scenario Clear:
#   Bikes Allocated (xik) = 5.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 92, Scenario Cloudy:
#   Bikes Allocated (xik) = 4.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 92, Scenario Rainy:
#   Bikes Allocated (xik) = 6.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 92, Scenario Sunny:
#   Bikes Allocated (xik) = 5.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 92, Scenario Clear:
#   Bikes Allocated (xik) = 4.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 93, Scenario Cloudy:
#   Bikes Allocated (xik) = 6.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 93, Scenario Rainy:
#   Bikes Allocated (xik) = 8.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 93, Scenario Sunny:
#   Bikes Allocated (xik) = 7.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 93, Scenario Clear:
#   Bikes Allocated (xik) = 6.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 94, Scenario Cloudy:
#   Bikes Allocated (xik) = 42.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 94, Scenario Rainy:
#   Bikes Allocated (xik) = 30.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 94, Scenario Sunny:
#   Bikes Allocated (xik) = 25.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 94, Scenario Clear:
#   Bikes Allocated (xik) = 36.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 95, Scenario Cloudy:
#   Bikes Allocated (xik) = 8.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 95, Scenario Rainy:
#   Bikes Allocated (xik) = 12.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 95, Scenario Sunny:
#   Bikes Allocated (xik) = 10.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 95, Scenario Clear:
#   Bikes Allocated (xik) = 9.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 96, Scenario Cloudy:
#   Bikes Allocated (xik) = 5.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 96, Scenario Rainy:
#   Bikes Allocated (xik) = 8.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 96, Scenario Sunny:
#   Bikes Allocated (xik) = 7.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 96, Scenario Clear:
#   Bikes Allocated (xik) = 6.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 97, Scenario Cloudy:
#   Bikes Allocated (xik) = 13.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 97, Scenario Rainy:
#   Bikes Allocated (xik) = 13.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 97, Scenario Sunny:
#   Bikes Allocated (xik) = 11.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 97, Scenario Clear:
#   Bikes Allocated (xik) = 10.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 98, Scenario Cloudy:
#   Bikes Allocated (xik) = 22.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 98, Scenario Rainy:
#   Bikes Allocated (xik) = 32.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 98, Scenario Sunny:
#   Bikes Allocated (xik) = 27.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 98, Scenario Clear:
#   Bikes Allocated (xik) = 24.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 99, Scenario Cloudy:
#   Bikes Allocated (xik) = 20.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 99, Scenario Rainy:
#   Bikes Allocated (xik) = 20.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 99, Scenario Sunny:
#   Bikes Allocated (xik) = 20.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 99, Scenario Clear:
#   Bikes Allocated (xik) = 20.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 100, Scenario Cloudy:
#   Bikes Allocated (xik) = 16.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 100, Scenario Rainy:
#   Bikes Allocated (xik) = 24.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 100, Scenario Sunny:
#   Bikes Allocated (xik) = 20.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 100, Scenario Clear:
#   Bikes Allocated (xik) = 18.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 101, Scenario Cloudy:
#   Bikes Allocated (xik) = 7.0
#   Unmet Demand Penalty = 0.0
#   Over Capacity Penalty = 0.0
# Station 101, Scenario Rainy:
#   Bikes Allocated (xik) = 5.0
#   Unmet Demand Penalty = 0.0
# ...
#   Relocate 6.0 bikes from Station 175 to Station 126
#   Relocate 6.0 bikes from Station 175 to Station 135
#   Relocate 1.0 bikes from Station 175 to Station 197
#   Relocate 5.0 bikes from Station 177 to Station 625
#   Relocate 2.0 bikes from Station 188 to Station 37
#   Relocate 2.0 bikes from Station 188 to Station 157
#   Relocate 5.0 bikes from Station 188 to Station 394
#   Relocate 10.0 bikes from Station 190 to Station 266
#   Relocate 5.0 bikes from Station 191 to Station 200
#   Relocate 5.0 bikes from Station 191 to Station 341
#   Relocate 1.0 bikes from Station 195 to Station 436
#   Relocate 10.0 bikes from Station 197 to Station 321
#   Relocate 5.0 bikes from Station 199 to Station 323
#   Relocate 12.0 bikes from Station 204 to Station 447
#   Relocate 6.0 bikes from Station 210 to Station 180
#   Relocate 3.0 bikes from Station 211 to Station 159
#   Relocate 4.0 bikes from Station 215 to Station 457
#   Relocate 13.0 bikes from Station 215 to Station 634
#   Relocate 2.0 bikes from Station 218 to Station 84
#   Relocate 15.0 bikes from Station 218 to Station 213
#   Relocate 11.0 bikes from Station 218 to Station 618
#   Relocate 8.0 bikes from Station 221 to Station 81
#   Relocate 13.0 bikes from Station 221 to Station 307
#   Relocate 2.0 bikes from Station 223 to Station 383
#   Relocate 13.0 bikes from Station 223 to Station 507
#   Relocate 2.0 bikes from Station 224 to Station 488
#   Relocate 6.0 bikes from Station 227 to Station 63
#   Relocate 18.0 bikes from Station 227 to Station 498
#   Relocate 5.0 bikes from Station 229 to Station 100
#   Relocate 9.0 bikes from Station 229 to Station 448
#   Relocate 21.0 bikes from Station 229 to Station 535
#   Relocate 2.0 bikes from Station 232 to Station 257
#   Relocate 1.0 bikes from Station 235 to Station 300
#   Relocate 3.0 bikes from Station 238 to Station 156
#   Relocate 10.0 bikes from Station 239 to Station 411
#   Relocate 16.0 bikes from Station 244 to Station 414
#   Relocate 1.0 bikes from Station 245 to Station 182
#   Relocate 7.0 bikes from Station 246 to Station 79
#   Relocate 13.0 bikes from Station 246 to Station 206
#   Relocate 19.0 bikes from Station 246 to Station 417
#   Relocate 5.0 bikes from Station 249 to Station 80
#   Relocate 1.0 bikes from Station 249 to Station 291
#   Relocate 7.0 bikes from Station 250 to Station 81
#   Relocate 27.0 bikes from Station 252 to Station 640
#   Relocate 24.0 bikes from Station 256 to Station 595
#   Relocate 12.0 bikes from Station 258 to Station 433
#   Relocate 1.0 bikes from Station 261 to Station 457
#   Relocate 11.0 bikes from Station 268 to Station 370
#   Relocate 3.0 bikes from Station 268 to Station 379
#   Relocate 10.0 bikes from Station 268 to Station 400
#   Relocate 4.0 bikes from Station 269 to Station 614
#   Relocate 3.0 bikes from Station 271 to Station 248
#   Relocate 25.0 bikes from Station 271 to Station 581
#   Relocate 3.0 bikes from Station 274 to Station 634
#   Relocate 1.0 bikes from Station 280 to Station 58
#   Relocate 1.0 bikes from Station 281 to Station 230
#   Relocate 8.0 bikes from Station 284 to Station 216
#   Relocate 2.0 bikes from Station 285 to Station 189
#   Relocate 10.0 bikes from Station 287 to Station 431
#   Relocate 4.0 bikes from Station 288 to Station 447
#   Relocate 12.0 bikes from Station 290 to Station 352
#   Relocate 12.0 bikes from Station 293 to Station 264
#   Relocate 5.0 bikes from Station 299 to Station 15
#   Relocate 1.0 bikes from Station 301 to Station 208
#   Relocate 1.0 bikes from Station 302 to Station 514
#   Relocate 5.0 bikes from Station 303 to Station 214
#   Relocate 12.0 bikes from Station 306 to Station 435
#   Relocate 7.0 bikes from Station 309 to Station 278
#   Relocate 7.0 bikes from Station 310 to Station 276
#   Relocate 6.0 bikes from Station 310 to Station 428
#   Relocate 4.0 bikes from Station 313 to Station 627
#   Relocate 14.0 bikes from Station 313 to Station 628
#   Relocate 5.0 bikes from Station 314 to Station 40
#   Relocate 18.0 bikes from Station 314 to Station 503
#   Relocate 5.0 bikes from Station 314 to Station 563
#   Relocate 8.0 bikes from Station 318 to Station 163
#   Relocate 7.0 bikes from Station 318 to Station 183
#   Relocate 7.0 bikes from Station 318 to Station 651
#   Relocate 10.0 bikes from Station 325 to Station 76
#   Relocate 4.0 bikes from Station 326 to Station 298
#   Relocate 22.0 bikes from Station 326 to Station 425
#   Relocate 1.0 bikes from Station 327 to Station 96
#   Relocate 2.0 bikes from Station 327 to Station 554
#   Relocate 3.0 bikes from Station 330 to Station 135
#   Relocate 4.0 bikes from Station 332 to Station 413
#   Relocate 4.0 bikes from Station 332 to Station 489
#   Relocate 5.0 bikes from Station 332 to Station 585
#   Relocate 4.0 bikes from Station 334 to Station 656
#   Relocate 22.0 bikes from Station 337 to Station 483
#   Relocate 6.0 bikes from Station 337 to Station 659
#   Relocate 9.0 bikes from Station 343 to Station 186
#   Relocate 8.0 bikes from Station 343 to Station 386
#   Relocate 1.0 bikes from Station 344 to Station 551
#   Relocate 3.0 bikes from Station 345 to Station 547
#   Relocate 3.0 bikes from Station 345 to Station 648
#   Relocate 5.0 bikes from Station 346 to Station 105
#   Relocate 5.0 bikes from Station 346 to Station 282
#   Relocate 8.0 bikes from Station 347 to Station 176
#   Relocate 1.0 bikes from Station 347 to Station 368
#   Relocate 3.0 bikes from Station 349 to Station 506
#   Relocate 12.0 bikes from Station 350 to Station 574
#   Relocate 2.0 bikes from Station 351 to Station 171
#   Relocate 16.0 bikes from Station 354 to Station 69
#   Relocate 9.0 bikes from Station 354 to Station 209
#   Relocate 10.0 bikes from Station 355 to Station 558
#   Relocate 12.0 bikes from Station 356 to Station 558
#   Relocate 5.0 bikes from Station 358 to Station 112
#   Relocate 9.0 bikes from Station 358 to Station 656
#   Relocate 8.0 bikes from Station 362 to Station 385
#   Relocate 4.0 bikes from Station 362 to Station 505
#   Relocate 13.0 bikes from Station 364 to Station 219
#   Relocate 5.0 bikes from Station 365 to Station 620
#   Relocate 29.0 bikes from Station 366 to Station 526
#   Relocate 2.0 bikes from Station 369 to Station 181
#   Relocate 4.0 bikes from Station 372 to Station 283
#   Relocate 1.0 bikes from Station 372 to Station 442
#   Relocate 2.0 bikes from Station 374 to Station 573
#   Relocate 8.0 bikes from Station 381 to Station 293
#   Relocate 4.0 bikes from Station 383 to Station 477
#   Relocate 14.0 bikes from Station 384 to Station 240
#   Relocate 1.0 bikes from Station 384 to Station 392
#   Relocate 20.0 bikes from Station 389 to Station 72
#   Relocate 33.0 bikes from Station 389 to Station 121
#   Relocate 10.0 bikes from Station 389 to Station 377
#   Relocate 1.0 bikes from Station 389 to Station 606
#   Relocate 18.0 bikes from Station 390 to Station 240
#   Relocate 2.0 bikes from Station 393 to Station 324
#   Relocate 3.0 bikes from Station 395 to Station 120
#   Relocate 4.0 bikes from Station 403 to Station 123
#   Relocate 2.0 bikes from Station 403 to Station 291
#   Relocate 4.0 bikes from Station 403 to Station 613
#   Relocate 5.0 bikes from Station 406 to Station 254
#   Relocate 31.0 bikes from Station 407 to Station 55
#   Relocate 2.0 bikes from Station 407 to Station 300
#   Relocate 2.0 bikes from Station 408 to Station 42
#   Relocate 2.0 bikes from Station 408 to Station 69
#   Relocate 12.0 bikes from Station 408 to Station 164
#   Relocate 7.0 bikes from Station 408 to Station 243
#   Relocate 9.0 bikes from Station 408 to Station 271
#   Relocate 7.0 bikes from Station 408 to Station 600
#   Relocate 6.0 bikes from Station 409 to Station 187
#   Relocate 19.0 bikes from Station 412 to Station 140
#   Relocate 4.0 bikes from Station 416 to Station 32
#   Relocate 1.0 bikes from Station 416 to Station 402
#   Relocate 8.0 bikes from Station 419 to Station 474
#   Relocate 3.0 bikes from Station 420 to Station 260
#   Relocate 2.0 bikes from Station 420 to Station 359
#   Relocate 7.0 bikes from Station 422 to Station 405
#   Relocate 10.0 bikes from Station 422 to Station 414
#   Relocate 9.0 bikes from Station 423 to Station 257
#   Relocate 6.0 bikes from Station 438 to Station 93
#   Relocate 2.0 bikes from Station 438 to Station 319
#   Relocate 3.0 bikes from Station 438 to Station 380
#   Relocate 2.0 bikes from Station 438 to Station 421
#   Relocate 20.0 bikes from Station 439 to Station 49
#   Relocate 10.0 bikes from Station 439 to Station 260
#   Relocate 10.0 bikes from Station 439 to Station 304
#   Relocate 3.0 bikes from Station 439 to Station 607
#   Relocate 14.0 bikes from Station 441 to Station 161
#   Relocate 8.0 bikes from Station 441 to Station 267
#   Relocate 7.0 bikes from Station 445 to Station 7
#   Relocate 3.0 bikes from Station 446 to Station 166
#   Relocate 6.0 bikes from Station 449 to Station 6
#   Relocate 8.0 bikes from Station 450 to Station 609
#   Relocate 11.0 bikes from Station 452 to Station 387
#   Relocate 10.0 bikes from Station 453 to Station 528
#   Relocate 3.0 bikes from Station 454 to Station 57
#   Relocate 4.0 bikes from Station 456 to Station 185
#   Relocate 1.0 bikes from Station 456 to Station 319
#   Relocate 3.0 bikes from Station 460 to Station 592
#   Relocate 15.0 bikes from Station 461 to Station 108
#   Relocate 7.0 bikes from Station 461 to Station 305
#   Relocate 8.0 bikes from Station 461 to Station 418
#   Relocate 1.0 bikes from Station 462 to Station 216
#   Relocate 6.0 bikes from Station 462 to Station 427
#   Relocate 5.0 bikes from Station 462 to Station 597
#   Relocate 1.0 bikes from Station 467 to Station 24
#   Relocate 5.0 bikes from Station 467 to Station 222
#   Relocate 8.0 bikes from Station 468 to Station 620
#   Relocate 8.0 bikes from Station 473 to Station 430
#   Relocate 4.0 bikes from Station 475 to Station 322
#   Relocate 9.0 bikes from Station 475 to Station 636
#   Relocate 3.0 bikes from Station 478 to Station 115
#   Relocate 1.0 bikes from Station 478 to Station 257
#   Relocate 13.0 bikes from Station 480 to Station 459
#   Relocate 8.0 bikes from Station 482 to Station 568
#   Relocate 18.0 bikes from Station 484 to Station 253
#   Relocate 10.0 bikes from Station 485 to Station 90
#   Relocate 17.0 bikes from Station 491 to Station 7
#   Relocate 8.0 bikes from Station 491 to Station 632
#   Relocate 3.0 bikes from Station 493 to Station 219
#   Relocate 5.0 bikes from Station 494 to Station 626
#   Relocate 1.0 bikes from Station 496 to Station 141
#   Relocate 2.0 bikes from Station 497 to Station 194
#   Relocate 1.0 bikes from Station 497 to Station 391
#   Relocate 8.0 bikes from Station 499 to Station 368
#   Relocate 2.0 bikes from Station 499 to Station 544
#   Relocate 28.0 bikes from Station 500 to Station 297
#   Relocate 3.0 bikes from Station 504 to Station 157
#   Relocate 16.0 bikes from Station 507 to Station 573
#   Relocate 2.0 bikes from Station 509 to Station 247
#   Relocate 5.0 bikes from Station 509 to Station 524
#   Relocate 15.0 bikes from Station 516 to Station 251
#   Relocate 11.0 bikes from Station 516 to Station 375
#   Relocate 2.0 bikes from Station 517 to Station 338
#   Relocate 2.0 bikes from Station 517 to Station 382
#   Relocate 2.0 bikes from Station 518 to Station 79
#   Relocate 4.0 bikes from Station 519 to Station 363
#   Relocate 1.0 bikes from Station 522 to Station 447
#   Relocate 13.0 bikes from Station 522 to Station 560
#   Relocate 1.0 bikes from Station 522 to Station 561
#   Relocate 13.0 bikes from Station 530 to Station 437
#   Relocate 7.0 bikes from Station 531 to Station 464
#   Relocate 3.0 bikes from Station 531 to Station 537
#   Relocate 2.0 bikes from Station 532 to Station 42
#   Relocate 2.0 bikes from Station 534 to Station 6
#   Relocate 11.0 bikes from Station 534 to Station 388
#   Relocate 6.0 bikes from Station 538 to Station 618
#   Relocate 5.0 bikes from Station 540 to Station 307
#   Relocate 10.0 bikes from Station 540 to Station 470
#   Relocate 1.0 bikes from Station 541 to Station 150
#   Relocate 10.0 bikes from Station 542 to Station 548
#   Relocate 35.0 bikes from Station 543 to Station 262
#   Relocate 2.0 bikes from Station 549 to Station 586
#   Relocate 1.0 bikes from Station 553 to Station 324
#   Relocate 8.0 bikes from Station 555 to Station 134
#   Relocate 10.0 bikes from Station 559 to Station 21
#   Relocate 16.0 bikes from Station 562 to Station 331
#   Relocate 25.0 bikes from Station 564 to Station 525
#   Relocate 7.0 bikes from Station 565 to Station 651
#   Relocate 29.0 bikes from Station 566 to Station 207
#   Relocate 5.0 bikes from Station 567 to Station 234
#   Relocate 11.0 bikes from Station 567 to Station 548
#   Relocate 5.0 bikes from Station 571 to Station 183
#   Relocate 5.0 bikes from Station 572 to Station 295
#   Relocate 2.0 bikes from Station 572 to Station 402
#   Relocate 2.0 bikes from Station 575 to Station 442
#   Relocate 7.0 bikes from Station 576 to Station 29
#   Relocate 20.0 bikes from Station 577 to Station 536
#   Relocate 5.0 bikes from Station 578 to Station 308
#   Relocate 15.0 bikes from Station 578 to Station 617
#   Relocate 13.0 bikes from Station 578 to Station 622
#   Relocate 3.0 bikes from Station 579 to Station 9
#   Relocate 1.0 bikes from Station 579 to Station 18
#   Relocate 2.0 bikes from Station 579 to Station 156
#   Relocate 5.0 bikes from Station 579 to Station 631
#   Relocate 5.0 bikes from Station 580 to Station 213
#   Relocate 8.0 bikes from Station 584 to Station 323
#   Relocate 10.0 bikes from Station 584 to Station 455
#   Relocate 13.0 bikes from Station 587 to Station 279
#   Relocate 3.0 bikes from Station 589 to Station 91
#   Relocate 8.0 bikes from Station 589 to Station 201
#   Relocate 4.0 bikes from Station 590 to Station 535
#   Relocate 4.0 bikes from Station 591 to Station 634
#   Relocate 7.0 bikes from Station 593 to Station 231
#   Relocate 8.0 bikes from Station 593 to Station 544
#   Relocate 17.0 bikes from Station 596 to Station 365
#   Relocate 1.0 bikes from Station 598 to Station 298
#   Relocate 4.0 bikes from Station 601 to Station 506
#   Relocate 8.0 bikes from Station 602 to Station 410
#   Relocate 13.0 bikes from Station 602 to Station 444
#   Relocate 4.0 bikes from Station 602 to Station 525
#   Relocate 1.0 bikes from Station 604 to Station 471
#   Relocate 12.0 bikes from Station 608 to Station 328
#   Relocate 10.0 bikes from Station 610 to Station 328
#   Relocate 14.0 bikes from Station 611 to Station 243
#   Relocate 16.0 bikes from Station 615 to Station 348
#   Relocate 11.0 bikes from Station 619 to Station 40
#   Relocate 10.0 bikes from Station 621 to Station 85
#   Relocate 38.0 bikes from Station 621 to Station 192
#   Relocate 14.0 bikes from Station 621 to Station 263
#   Relocate 3.0 bikes from Station 621 to Station 612
#   Relocate 5.0 bikes from Station 623 to Station 212
#   Relocate 6.0 bikes from Station 623 to Station 260
#   Relocate 11.0 bikes from Station 624 to Station 367
#   Relocate 8.0 bikes from Station 624 to Station 605
#   Relocate 4.0 bikes from Station 625 to Station 632
#   Relocate 4.0 bikes from Station 630 to Station 117
#   Relocate 13.0 bikes from Station 630 to Station 272
#   Relocate 17.0 bikes from Station 630 to Station 565
#   Relocate 12.0 bikes from Station 633 to Station 109
#   Relocate 6.0 bikes from Station 633 to Station 632
#   Relocate 2.0 bikes from Station 635 to Station 279
#   Relocate 16.0 bikes from Station 641 to Station 501
#   Relocate 1.0 bikes from Station 641 to Station 573
#   Relocate 2.0 bikes from Station 642 to Station 102
#   Relocate 12.0 bikes from Station 645 to Station 362
#   Relocate 6.0 bikes from Station 646 to Station 440
#   Relocate 15.0 bikes from Station 647 to Station 150
#   Relocate 9.0 bikes from Station 650 to Station 379
#   Relocate 2.0 bikes from Station 650 to Station 637
#   Relocate 3.0 bikes from Station 652 to Station 262
#   Relocate 3.0 bikes from Station 652 to Station 352
#   Relocate 2.0 bikes from Station 652 to Station 427
#   Relocate 16.0 bikes from Station 653 to Station 632
#   Relocate 15.0 bikes from Station 654 to Station 182
#   Relocate 3.0 bikes from Station 660 to Station 429
#   Relocate 18.0 bikes from Station 661 to Station 90
#   Relocate 27.0 bikes from Station 661 to Station 336
#   Relocate 13.0 bikes from Station 661 to Station 429
